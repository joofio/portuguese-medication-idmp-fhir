# %%
import pyodbc
import pandas as pd
import json
import requests
import re
from os import listdir
from os.path import isfile, join

import glob
import os
#for OSX
import jaydebeapi
import subprocess
from jinja2 import Template
import pandas as pd
from pathlib import Path
import numpy as np

# %%
db_path = "../CITS20220208AH.mdb"

#/Users/joaoalmeida
ucanaccess_jars = [
    "/Users/joaoalmeida/Downloads/UCanAccess-5.0.1.bin/ucanaccess-5.0.1.jar",
    "/Users/joaoalmeida/Downloads/UCanAccess-5.0.1.bin/lib/commons-lang3-3.8.1.jar",
    "/Users/joaoalmeida/Downloads/UCanAccess-5.0.1.bin/lib/commons-logging-1.2.jar",
    "/Users/joaoalmeida/Downloads/UCanAccess-5.0.1.bin/lib/hsqldb-2.5.0.jar",
    "/Users/joaoalmeida/Downloads/UCanAccess-5.0.1.bin/lib/jackcess-3.0.1.jar",
]
classpath = ":".join(ucanaccess_jars)
cnxn = jaydebeapi.connect(
    "net.ucanaccess.jdbc.UcanaccessDriver",
    f"jdbc:ucanaccess://{db_path};newDatabaseVersion=V2010",
    ["", ""],
    classpath
    )
crsr = cnxn.cursor()

# %% [markdown]
# ## Selecting Drugs

# %%
dd="""
               select e.*,m.Dosagem,m.Nome,m.ind_Generico,ff.descr AS form_farm_descr,ff.Forma_Farm_ID,te.DESCR as tipo_emb_descr,
                tp.DESCR as Tipo_Prod_descr, gh.Descr as Grupo_Hom_descr, ea.Descr as Estado_AIM_Descr, rcdp.Descr as Class_Disp_descr,
                ta.Descr as Titular_AIM_descr, 
                dci.descr AS DCIPT_descr, dci.DCIPT_ID 
               from (((((((((
                   Embalagem as e

                INNER join produto as m on m.prod_id=e.prod_ID)
                left join ref_Tipo_emb as te on te.Tipo_emb_ID=e.Tipo_emb_ID )
                left join ref_Tipo_produto as tp on tp.Tipo_Produto_ID=m.Tipo_Produto_ID)
                left join ref_Forma_Farm as ff on ff.Forma_Farm_ID=m.Forma_Farm_ID)
                left join ref_Grupo_Hom as gh on gh.Grupo_Hom_cod=e.Grupo_Hom_cod)
                left join ref_Estado_AIM as ea on ea.Estado_AIM_ID=m.Estado_AIM_ID)
                left join lnk_prod_CLASS_DISP as cd on cd.prod_id=m.prod_id)
                left join ref_CLASS_DISPENSA_PROD as rcdp on rcdp.class_disp_prod_id=cd.class_disp_prod_id)
                left join ref_Titular_AIM as ta on ta.Titular_AIM_ID=m.Titular_AIM_ID)
                left join ref_DCIPT as dci on dci.DCIPT_ID=m.DCIPT_ID
                where ea.Estado_AIM_ID=1 """

dd_ = pd.read_sql(dd,cnxn)
list_meds=dd_[~pd.isna(dd_["CNPEM"])]["DCIPT_ID"].unique()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/py3/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
list_meds=[str(int(float(k))) for k in list_meds]

# %%
produto_sql="""select * from REF_DCIPT where IND_ATIVO='S' and DCIPT_ID in ({})""".format(",".join(list(list_meds)))
med_ids = pd.read_sql(produto_sql,cnxn)
med_ids
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/py3/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#       DCIPT_ID                                              DESCR ABREV_CHNM  \
# 0            1                         Acetilsalicilato de lisina       None
# 1            2                                          Aciclovir       None
# 2            3                                         Alopurinol       None
# 3            4                                         Alprazolam       None
# 4            5                                          Amicacina       None
# ...        ...                                                ...        ...
# 1616      4059                            Casirivimab + Imdevimab       None
# 1617      4063                                         Vosoritida       None
# 1618      4064                                        Regdanvimab       None
# 1619      4065                              Fumarato de diroximel       None
# 1620      4067  Vacina de proteína recombinante contra COVID-1...       None
#
#      IND_ATIVO
# 0            S
# 1            S
# 2            S
# 3            S
# 4            S
# ...        ...
# 1616         S
# 1617         S
# 1618         S
# 1619         S
# 1620         S
#
# [1621 rows x 4 columns]

# %%
dcipt_ids=med_ids["DCIPT_ID"].values.tolist()
dcipt_ids=[str(d) for d in dcipt_ids]

# %%
ss="""select * from lnk_prod_CLASS_DISP where PROD_ID=3371"""
sst = pd.read_sql(ss,cnxn)
#package_medicinal_product.to_csv("test_package.csv")
#from this, go downwards
sst
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/py3/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    PROD_ID  CLASS_DISP_PROD_ID
# 0     3371                   4
# 1     3371                  10

# %%
ss="""select * from ref_CLASS_DISPENSA_PROD"""
sst = pd.read_sql(ss,cnxn)
#package_medicinal_product.to_csv("test_package.csv")
#from this, go downwards
sst
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/py3/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#     CLASS_DISP_PROD_ID                                 DESCR IND_ATIVO
# 0                    1                                 MNSRM         S
# 1                    4                         MSRM especial         S
# 2                    5                         MSRM restrita         S
# 3                    6                                  MSRM         S
# 4                    7                               MSRM-EF         S
# 5                    8                              MNSRM-EF         S
# 6                   10             MSRM restrita - Alínea a)         S
# 7                   11             MSRM restrita - Alínea b)         S
# 8                   12             MSRM restrita - Alínea c)         S
# 9                   13  MSRM especial e restrita - Alínea a)         N
# 10                  14  MSRM especial e restrita - Alínea b)         N
# 11                  15  MSRM especial e restrita - Alínea c)         N
# 12                  20                  Embalagem hospitalar         N
# 13                 100              Alinea a) do D.L. 306/97         N
# 14                 101              Alinea b) do D.L. 306/97         N
# 15                 102              Alinea c) do D.L. 306/97         N
# 16                 103              MSRM especial e restrita         N

# %%
package_medicinal_product_sql="""
               select e.*,m.Dosagem,m.Nome,m.ind_Generico,ff.descr AS form_farm_descr,ff.Forma_Farm_ID,te.DESCR as tipo_emb_descr,
                tp.DESCR as Tipo_Prod_descr, gh.Descr as Grupo_Hom_descr, ea.Descr as Estado_AIM_Descr, 
                ta.Descr as Titular_AIM_descr, 
                dci.descr AS DCIPT_descr, dci.DCIPT_ID 
               from (((((((
                   Embalagem as e

                INNER join produto as m on m.prod_id=e.prod_ID)
                left join ref_Tipo_emb as te on te.Tipo_emb_ID=e.Tipo_emb_ID )
                left join ref_Tipo_produto as tp on tp.Tipo_Produto_ID=m.Tipo_Produto_ID)
                left join ref_Forma_Farm as ff on ff.Forma_Farm_ID=m.Forma_Farm_ID)
                left join ref_Grupo_Hom as gh on gh.Grupo_Hom_cod=e.Grupo_Hom_cod)
                left join ref_Estado_AIM as ea on ea.Estado_AIM_ID=m.Estado_AIM_ID)
                left join ref_Titular_AIM as ta on ta.Titular_AIM_ID=m.Titular_AIM_ID)
                left join ref_DCIPT as dci on dci.DCIPT_ID=m.DCIPT_ID
                where ea.Estado_AIM_ID=1  and dci.DCIPT_ID in ({})""".format(",".join(dcipt_ids))

package_medicinal_product = pd.read_sql(package_medicinal_product_sql,cnxn)
#package_medicinal_product.to_csv("test_package.csv")
#from this, go downwards
package_medicinal_product
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/py3/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#         EMB_ID  PROD_ID NR_REGISTO                                      DESCR  \
# 0            1        1    9929539                    Blister - 20 unidade(s)
# 1            3        1    9900423                    Blister - 40 unidade(s)
# 2            6        3    9935916                    Blister - 20 unidade(s)
# 3            7        3    9935924                   Blister - 200 unidade(s)
# 4           12        8    9650002  Frasco conta-gotas - 1 unidade(s) - 50 ml
# ...        ...      ...        ...                                        ...
# 46793  2205975    35283    5830625      Frasco para injetáveis - 5 unidade(s)
# 46794  2206095   685184       None         Recipiente unidose - 60 unidade(s)
# 46795  2206215   685284       None             Frasco - 1 unidade(s) - 250 ml
# 46796  2206335   685444       None              Ampola - 1 unidade(s) - 10 ml
# 46797  2206355   685464       None                      Frasco - 6 unidade(s)
#
#       GRUPO_HOM_COD  QUANT_TOT  UNID_QUANT_TOT_ID  QUANTIDADE  UNID_QUANT_ID  \
# 0            GH0000       20.0                 32         NaN            NaN
# 1            GH0000       40.0                 32         NaN            NaN
# 2            GH0000       20.0                 32         NaN            NaN
# 3            GH0000      200.0                 32         NaN            NaN
# 4            GH0000        1.0                 32        50.0           12.0
# ...             ...        ...                ...         ...            ...
# 46793        GH0000        5.0                 32         NaN            NaN
# 46794        GH0000       60.0                 32         NaN            NaN
# 46795        GH0000        1.0                 32       250.0           12.0
# 46796        GH0000        1.0                 32        10.0           12.0
# 46797        GH0000        6.0                 32         NaN            NaN
#
#        TIPO_EMB_ID  ...  IND_GENERICO                          DESCR  \
# 0              NaN  ...             N                     Comprimido
# 1              NaN  ...             N                     Comprimido
# 2              NaN  ...             N                        Cápsula
# 3              NaN  ...             N                        Cápsula
# 4              NaN  ...             N                   Solução oral
# ...            ...  ...           ...                            ...
# 46793          NaN  ...             S  Pó para solução para perfusão
# 46794          NaN  ...             N               Colírio, solução
# 46795          NaN  ...             N                 Suspensão oral
# 46796          NaN  ...             N              Solução injetável
# 46797          NaN  ...             N    Pó para suspensão injetável
#
#        FORMA_FARM_ID DESCR                   DESCR DESCR       DESCR  \
# 0              271.0  None  Medicamento Uso Humano  None  Autorizado
# 1              271.0  None  Medicamento Uso Humano  None  Autorizado
# 2               29.0  None  Medicamento Uso Humano  None  Autorizado
# 3               29.0  None  Medicamento Uso Humano  None  Autorizado
# 4                4.0  None  Medicamento Uso Humano  None  Autorizado
# ...              ...   ...                     ...   ...         ...
# 46793          217.0  None  Medicamento Uso Humano  None  Autorizado
# 46794          123.0  None  Medicamento Uso Humano  None  Autorizado
# 46795            5.0  None  Medicamento Uso Humano  None  Autorizado
# 46796          207.0  None  Medicamento Uso Humano  None  Autorizado
# 46797          211.0  None  Medicamento Uso Humano  None  Autorizado
#
#                                                    DESCR  \
# 0                                 Perrigo Portugal, Lda.
# 1                                 Perrigo Portugal, Lda.
# 2      Sidefarma - Sociedade Industrial de Expansão F...
# 3      Sidefarma - Sociedade Industrial de Expansão F...
# 4      Sidefarma - Sociedade Industrial de Expansão F...
# ...                                                  ...
# 46793                Hikma Farmacêutica (Portugal), S.A.
# 46794                                Trimb Healthcare AB
# 46795                               Dr. Falk Pharma GmbH
# 46796                                   GE Healthcare BV
# 46797                                     Not applicable
#
#                                  DESCR DCIPT_ID
# 0               Ácido acetilsalicílico      117
# 1               Ácido acetilsalicílico      117
# 2                              Retinol      981
# 3                              Retinol      981
# 4                        Ginkgo biloba      616
# ...                                ...      ...
# 46793  Amoxicilina + Ácido clavulânico        9
# 46794                      Pilocarpina      918
# 46795           Ácido ursodesoxicólico     1184
# 46796           Iodeto (131I) de sódio     2207
# 46797       Tecnécio (99mTc) macrosalb     2048
#
# [46798 rows x 37 columns]

# %%
#get-columns-name
columns_sql="""SELECT * FROM Embalagem limit 5"""
col_name=pd.read_sql(columns_sql,cnxn).columns.tolist()
col_name.extend(["Dosagem","Nome","ind_generico","form_farm_descr","Forma_farm_id","tipo_emb_descr","Tipo_prod_descr","Grupo_hom_descr","Estado_AIM_descr","Titular_AIM_descr","DCIPT_descr","DCIPT_ID"])
col_name
package_medicinal_product.columns=col_name
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/py3/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
def create_package_name(row):
    if None in [row["Dosagem"],row["Nome"],row["form_farm_descr"],row["DESCR"]]:
        print( row["Nome"],row["Dosagem"],row["form_farm_descr"],row["DESCR"],row["EMB_ID"])
        return None
    else:
        return row["Nome"] +" "+row["Dosagem"]+" "+row["form_farm_descr"] + " " + row["DESCR"]

package_medicinal_product["full_name"]=package_medicinal_product.apply(create_package_name,axis=1)
# Out:
# Tagamet 200 mg/ 2ml None Ampola - 10 unidade(s) - 2 ml 2203536

# %%
def parse_single_instance(col,tot):
    if col.count("/")==0: #no denominator
    # print(parse_num(col))
        numerator_value,numerator_unit=parse_num(col,tot)
        return numerator_value,numerator_unit,None,None
    elif col.count("/")==1:
        #print(col)
        num=col.split("/")[0]
        dem=col.split("/")[1]
    #     print(num,"   >->",dem)
        numerator_value,numerator_unit=parse_num(num,tot)
        denominator_value,denominator_unit=parse_dem(dem,tot)
        # print(numerator_value,numerator_unit,denominator_value,denominator_unit)
        return numerator_value,numerator_unit,denominator_value,denominator_unit
    else:
        raise ValueError(col,tot)
def parse_num(num,col):
    numerator_value_tag="\d+\.?\d{0,3}"
    numerator_unit_tag="\s?(\D+)$"
    try:
        numerator_value=re.findall(numerator_value_tag,num)[0].strip()
    except:
        #raise ValueError(num,col)
        print(num,col,"Error on numerator value")
        numerator_value=None
    try:
        numerator_unit=str(re.findall(numerator_unit_tag,num)[0].strip())
    except:
        #raise ValueError(num,col)
        print(num,col,"Error on numerator unit")
        numerator_unit=None


    return numerator_value,numerator_unit
def parse_dem(dem,col):
    """
    2 ml
    g 
    0.5 ml
    0.5ml
    ml
    """
    denominator_unit_tag=re.compile("\s?(\D+)$")
    denominator_value_tag=re.compile("\d\.?\d?")
    #print(dem)
    try:
        if denominator_value_tag.match(dem): #if has number
            denominator_value=str(denominator_value_tag.findall(dem)[0].strip())
        else: #defaults to 1
            denominator_value=1
        
        denominator_unit=denominator_unit_tag.findall(dem)[0].strip()

    except:
        raise ValueError(dem)
    return denominator_value,denominator_unit
    # print(denominator_unit)


def parse_strength(row):
  
    """
    cases:
    50mg
    50 mg
    0.5mg/ml
    5mg/10ml
    1 mg/ml
    1200 mg/6 ml + 800 U.I./6 ml
    100 U.I./ml (25% + 75%)
    100 U.I./ml (30% + 70%)
    CCID50 10e6 CCID50
    800mg + 150mg + 200mg + 10mg
    """
  
    col=row["Dosagem"]
    if col in ["Associação","Combinação","associação"]:
        return None,None,None,None
    if col in "CCID50 10e6 CCID50":
        return None,None,None,None #what to do?
   # print(col)
    if col.count("+")==0:

       return parse_single_instance(col,col)
    else:
     #   print(col)
        numerator_unit_list=[]
        denominator_unit_list=[]
        numerator_value_list=[]
        denominator_value_list=[]
        for prod in col.split("+"):
            numerator_value,numerator_unit,denominator_value,denominator_unit=parse_single_instance(prod,col)
            numerator_unit_list.append(numerator_unit)
            if denominator_unit:
                denominator_unit_list.append(denominator_unit)
            
            numerator_value_list.append(numerator_value)
            if denominator_value:
                denominator_value_list.append(denominator_value)
        if len(denominator_value_list)>0:

            return numerator_value_list,numerator_unit_list,denominator_value_list,denominator_unit_list
        else:   
            return numerator_value_list,numerator_unit_list,None,None

package_medicinal_product[["numerator_value","numerator_unit","denominator_value","denominator_unit"]]=package_medicinal_product.apply(parse_strength,axis=1,result_type='expand')

# %%
package_medicinal_product[package_medicinal_product["EMB_ID"]==134]["Dosagem"]
# Out:
# 37    Associação
# Name: Dosagem, dtype: object

# %%
package_medicinal_product["full_name"]
# Out:
# 0            AAS 500 mg Comprimido Blister - 20 unidade(s)
# 1            AAS 500 mg Comprimido Blister - 40 unidade(s)
# 2        A-Vite 50000 U.I. Cápsula Blister - 20 unidade(s)
# 3        A-Vite 50000 U.I. Cápsula Blister - 200 unidad...
# 4        Abolibe Forte 40 mg/ml Solução oral Frasco con...
#                                ...
# 46793    Amoxicilina + Ácido Clavulânico Hikma 2000+200...
# 46794    Pilokarpin Trimb  20 mg/ml Colírio, solução Re...
# 46795    Ursofalk 250 mg/5 ml Suspensão oral Frasco - 1...
# 46796    Sodium Iodide Injection GE Healthcare 370 MBq/...
# 46797    Makro-albumon 2 mg Pó para suspensão injetável...
# Name: full_name, Length: 46798, dtype: object

# %%
package_medicinal_product[["full_name","Dosagem","numerator_value","numerator_unit","denominator_value","denominator_unit"]].iloc[50:90,:]
# Out:
#                                             full_name  \
# 50  Adenoscan 3 mg/ml Solução para perfusão Frasco...
# 51  Adrenalina Labesfal 1 mg/1 ml Solução injetáve...
# 52  Adrenalina Labesfal 1 mg/1 ml Solução injetáve...
# 53  Adrenalina Labesfal 1 mg/1 ml Solução injetáve...
# 54  Adrenalina Labesfal 1 mg/1 ml Solução injetáve...
# 55  Adrenalina Labesfal 2 mg/1 ml Solução injetáve...
# 56  Adrenalina Labesfal 2 mg/1 ml Solução injetáve...
# 57  Adrenalina Labesfal 2 mg/1 ml Solução injetáve...
# 58  Adrenalina Labesfal 2 mg/1 ml Solução injetáve...
# 59  Adrenalina Labesfal 0.1 mg/1 ml Solução injetá...
# 60  Adrenalina Labesfal 0.1 mg/1 ml Solução injetá...
# 61  Adrenalina Labesfal 0.1 mg/1 ml Solução injetá...
# 62  Adrenalina Labesfal 0.1 mg/1 ml Solução injetá...
# 63  Adrenalina Labesfal 0.25 mg/1 ml Solução injet...
# 64  Adrenalina Labesfal 0.25 mg/1 ml Solução injet...
# 65  Adrenalina Labesfal 0.25 mg/1 ml Solução injet...
# 66  Adrenalina Labesfal 0.25 mg/1 ml Solução injet...
# 67  Thyrogen 0.9 mg Pó para solução injetável Fras...
# 68  Adt 10 mg Comprimido revestido Blister - 60 un...
# 69  Adt 25 mg Comprimido revestido Blister - 60 un...
# 70  Adt 75 mg Comprimido revestido Blister - 60 un...
# 71  Advantan 1 mg/g Creme Bisnaga - 1 unidade(s) -...
# 72  Advantan 1 mg/g Emulsão cutânea Bisnaga - 1 un...
# 73  Advantan 1 mg/g Emulsão cutânea Bisnaga - 1 un...
# 74  Advantan 1 mg/g Pomada Bisnaga - 1 unidade(s) ...
# 75  Aero-Om 42 mg Comprimido para mastigar Blister...
# 76  Aero-Om 42 mg Comprimido para mastigar Blister...
# 77  Aero-Om 42 mg Comprimido para mastigar Blister...
# 78  Afebryl 300 mg + 200 mg + 300 mg Comprimido ef...
# 79  Agiocur 22 mg/g + 650 mg/g Granulado Caixa - 1...
# 80  Agiocur 22 mg/g + 650 mg/g Granulado Caixa - 1...
# 81  Agiolax Associação Granulado Caixa - 1 unidade...
# 82  Agiolax Associação Granulado Caixa - 1 unidade...
# 83  Agiolax Associação Granulado Caixa - 1 unidade...
# 84  Água Bidestilada Estéril Braun 100 % Solução i...
# 85   Akineton 2 mg Comprimido Blister - 20 unidade(s)
# 86   Akineton 2 mg Comprimido Blister - 50 unidade(s)
# 87  Akineton 5 mg/1 ml Solução injetável Ampola - ...
# 88  Akineton Retard 4 mg Comprimido de libertação ...
# 89  Akineton Retard 4 mg Comprimido de libertação ...
#
#                      Dosagem  numerator_value numerator_unit  \
# 50                   3 mg/ml                3             mg
# 51                 1 mg/1 ml                1             mg
# 52                 1 mg/1 ml                1             mg
# 53                 1 mg/1 ml                1             mg
# 54                 1 mg/1 ml                1             mg
# 55                 2 mg/1 ml                2             mg
# 56                 2 mg/1 ml                2             mg
# 57                 2 mg/1 ml                2             mg
# 58                 2 mg/1 ml                2             mg
# 59               0.1 mg/1 ml              0.1             mg
# 60               0.1 mg/1 ml              0.1             mg
# 61               0.1 mg/1 ml              0.1             mg
# 62               0.1 mg/1 ml              0.1             mg
# 63              0.25 mg/1 ml             0.25             mg
# 64              0.25 mg/1 ml             0.25             mg
# 65              0.25 mg/1 ml             0.25             mg
# 66              0.25 mg/1 ml             0.25             mg
# 67                    0.9 mg              0.9             mg
# 68                     10 mg               10             mg
# 69                     25 mg               25             mg
# 70                     75 mg               75             mg
# 71                    1 mg/g                1             mg
# 72                    1 mg/g                1             mg
# 73                    1 mg/g                1             mg
# 74                    1 mg/g                1             mg
# 75                     42 mg               42             mg
# 76                     42 mg               42             mg
# 77                     42 mg               42             mg
# 78  300 mg + 200 mg + 300 mg  [300, 200, 300]   [mg, mg, mg]
# 79        22 mg/g + 650 mg/g        [22, 650]       [mg, mg]
# 80        22 mg/g + 650 mg/g        [22, 650]       [mg, mg]
# 81                Associação             None           None
# 82                Associação             None           None
# 83                Associação             None           None
# 84                     100 %              100              %
# 85                      2 mg                2             mg
# 86                      2 mg                2             mg
# 87                 5 mg/1 ml                5             mg
# 88                      4 mg                4             mg
# 89                      4 mg                4             mg
#
#    denominator_value denominator_unit
# 50                 1               ml
# 51                 1               ml
# 52                 1               ml
# 53                 1               ml
# 54                 1               ml
# 55                 1               ml
# 56                 1               ml
# 57                 1               ml
# 58                 1               ml
# 59                 1               ml
# 60                 1               ml
# 61                 1               ml
# 62                 1               ml
# 63                 1               ml
# 64                 1               ml
# 65                 1               ml
# 66                 1               ml
# 67              None             None
# 68              None             None
# 69              None             None
# 70              None             None
# 71                 1                g
# 72                 1                g
# 73                 1                g
# 74                 1                g
# 75              None             None
# 76              None             None
# 77              None             None
# 78              None             None
# 79            [1, 1]           [g, g]
# 80            [1, 1]           [g, g]
# 81              None             None
# 82              None             None
# 83              None             None
# 84              None             None
# 85              None             None
# 86              None             None
# 87                 1               ml
# 88              None             None
# 89              None             None

# %%
#800mg + 150mg + 200mg + 10mg
package_medicinal_product[package_medicinal_product["Dosagem"]=="800mg + 150mg + 200mg + 10mg"]
# Out:
#         EMB_ID  PROD_ID NR_REGISTO                   DESCR GRUPO_HOM_COD  \
# 41215  2102050   622642    5728373  Frasco - 30 unidade(s)        GH0000
#
#        QUANT_TOT  UNID_QUANT_TOT_ID  QUANTIDADE  UNID_QUANT_ID  TIPO_EMB_ID  \
# 41215       30.0                 32         NaN            NaN          NaN
#
#        ...  Grupo_hom_descr  Estado_AIM_descr  \
# 41215  ...             None        Autorizado
#
#                       Titular_AIM_descr  \
# 41215  Janssen-Cilag International N.V.
#
#                                              DCIPT_descr DCIPT_ID  \
# 41215  Darunavir + Cobicistate + Emtricitabina + Teno...     3743
#
#                                                full_name      numerator_value  \
# 41215  Symtuza 800mg + 150mg + 200mg + 10mg Comprimid...  [800, 150, 200, 10]
#
#          numerator_unit denominator_value denominator_unit
# 41215  [mg, mg, mg, mg]              None             None
#
# [1 rows x 42 columns]

# %%
def transform_dcipt_to_list(row):
    """ transform combinations to strucutred
    """
    if "+" in row["DCIPT_descr"]:
        result=row["DCIPT_descr"].split("+")
        #print(row["DCIPT_descr"])
        return [prod.strip() for prod in result]
    return row["DCIPT_descr"]
package_medicinal_product["DCIPT_descr_parse"]=package_medicinal_product.apply(transform_dcipt_to_list,axis=1)

# %%
package_medicinal_product.head()
# Out:
#    EMB_ID  PROD_ID NR_REGISTO                                      DESCR  \
# 0       1        1    9929539                    Blister - 20 unidade(s)
# 1       3        1    9900423                    Blister - 40 unidade(s)
# 2       6        3    9935916                    Blister - 20 unidade(s)
# 3       7        3    9935924                   Blister - 200 unidade(s)
# 4      12        8    9650002  Frasco conta-gotas - 1 unidade(s) - 50 ml
#
#   GRUPO_HOM_COD  QUANT_TOT  UNID_QUANT_TOT_ID  QUANTIDADE  UNID_QUANT_ID  \
# 0        GH0000       20.0                 32         NaN            NaN
# 1        GH0000       40.0                 32         NaN            NaN
# 2        GH0000       20.0                 32         NaN            NaN
# 3        GH0000      200.0                 32         NaN            NaN
# 4        GH0000        1.0                 32        50.0           12.0
#
#    TIPO_EMB_ID  ...  Estado_AIM_descr  \
# 0          NaN  ...        Autorizado
# 1          NaN  ...        Autorizado
# 2          NaN  ...        Autorizado
# 3          NaN  ...        Autorizado
# 4          NaN  ...        Autorizado
#
#                                    Titular_AIM_descr             DCIPT_descr  \
# 0                             Perrigo Portugal, Lda.  Ácido acetilsalicílico
# 1                             Perrigo Portugal, Lda.  Ácido acetilsalicílico
# 2  Sidefarma - Sociedade Industrial de Expansão F...                 Retinol
# 3  Sidefarma - Sociedade Industrial de Expansão F...                 Retinol
# 4  Sidefarma - Sociedade Industrial de Expansão F...           Ginkgo biloba
#
#   DCIPT_ID                                          full_name numerator_value  \
# 0      117      AAS 500 mg Comprimido Blister - 20 unidade(s)             500
# 1      117      AAS 500 mg Comprimido Blister - 40 unidade(s)             500
# 2      981  A-Vite 50000 U.I. Cápsula Blister - 20 unidade(s)           50000
# 3      981  A-Vite 50000 U.I. Cápsula Blister - 200 unidad...           50000
# 4      616  Abolibe Forte 40 mg/ml Solução oral Frasco con...              40
#
#   numerator_unit denominator_value denominator_unit       DCIPT_descr_parse
# 0             mg              None             None  Ácido acetilsalicílico
# 1             mg              None             None  Ácido acetilsalicílico
# 2           U.I.              None             None                 Retinol
# 3           U.I.              None             None                 Retinol
# 4             mg                 1               ml           Ginkgo biloba
#
# [5 rows x 43 columns]

# %%
def transform_list_to_string(x):
    if type(x)==list and len(x)>0:
        x=[str(k) for k in x]
        return ";".join(x)
    return x
package_medicinal_product["numerator_value"]=package_medicinal_product["numerator_value"].apply(transform_list_to_string)
package_medicinal_product["numerator_unit"]=package_medicinal_product["numerator_unit"].apply(transform_list_to_string)
package_medicinal_product["denominator_value"]=package_medicinal_product["denominator_value"].apply(transform_list_to_string)
package_medicinal_product["denominator_unit"]=package_medicinal_product["denominator_unit"].apply(transform_list_to_string)
package_medicinal_product["DCIPT_descr_parse"]=package_medicinal_product["DCIPT_descr_parse"].apply(transform_list_to_string)

# %%
routes_sql="""select lpva.PROD_ID,lpva.VIA_ADMIN_ID,rva.DESCR from lnk_prod_via_admin lpva 
left join ref_via_admin rva on lpva.via_admin_id=rva.via_admin_id
  """
routes = pd.read_sql(routes_sql,cnxn)
routes
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/py3/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#        PROD_ID  VIA_ADMIN_ID              DESCR
# 0        50803            48           Via oral
# 1       623263            48           Via oral
# 2         1593            48           Via oral
# 3        49252            48           Via oral
# 4       623622            48           Via oral
# ...        ...           ...                ...
# 20110   656665            48           Via oral
# 20111   652044            48           Via oral
# 20112   652045            48           Via oral
# 20113   653665            42    Via intravenosa
# 20114   653665            30  Via intramuscular
#
# [20115 rows x 3 columns]

# %%
def concatenate_values_from_list(x):
   # print(type(x))
   # print(x.values)
    #print(";".join([str(d) for d in x.values]))
    return ";".join([str(d) for d in x.values])

# %%
# get CPARM and mapp to infarmed
cparm_routes=pd.read_excel("../CPARM_V1.0.xlsx","Routes of Administration")
cparm_routes["mapping_term"]=cparm_routes["Preferred Term (PT) PT | Termo de Preferência PT"]
cparm_routes.loc[cparm_routes["Code EDQM |Código EDQM"]==20020000,"mapping_term"]="Via inalatória"
cparm_routes.loc[cparm_routes["Code EDQM |Código EDQM"]==20047000,"mapping_term"]="Via intravítreo"
cparm_routes.loc[cparm_routes["Code EDQM |Código EDQM"]==20025500,"mapping_term"]="Uso intracameral"
cparm_routes.loc[len(cparm_routes.index)] = cparm_routes[cparm_routes["Code EDQM |Código EDQM"]==20003000].values[0]
cparm_routes.iloc[-1,-1] = "Uso epicutâneo"

# %%
mapp_routes_edqm=routes.merge(cparm_routes,how="left",left_on="DESCR",right_on="mapping_term")
mapp_routes_edqm[mapp_routes_edqm["Code EDQM |Código EDQM"].isnull()]
#Uso epicutâneo
# Out:
# Empty DataFrame
# Columns: [PROD_ID, VIA_ADMIN_ID, DESCR, Code EDQM |Código EDQM, Fully Specified Name (FSN) EN | Termo Totalmente Especificado EN, Definition EN | Definição EN, Preferred Term (PT) PT | Termo de Preferência PT, Definition PT | Definição PT, Domain | Âmbito , Version | Versão, Type of Change | Tipo Alteração, mapping_term]
# Index: []

# %%
routes_agg=mapp_routes_edqm.groupby("PROD_ID").aggregate({"VIA_ADMIN_ID":concatenate_values_from_list,"DESCR":concatenate_values_from_list,"Code EDQM |Código EDQM":concatenate_values_from_list,"Fully Specified Name (FSN) EN | Termo Totalmente Especificado EN":concatenate_values_from_list}).reset_index()
routes_agg.columns=["PROD_ID","routes_id","routes_descr","edqm_routes_id","edqm_routes_descr_en"]

# %%
product_with_routes=package_medicinal_product.merge(routes_agg,on="PROD_ID",how="left")

# %%
atc_sql="""select lpa.PROD_ID,lpa.ATC_COD,fa.DESCR from lnk_prod_atc lpa
left join ref_atc fa on lpa.atc_cod=fa.atc_cod
  """
atc = pd.read_sql(atc_sql,cnxn)
atc
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/py3/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#        PROD_ID  ATC_COD                 DESCR
# 0       600228  N03AX14         levetiracetam
# 1        52417  N03AX14         levetiracetam
# 2        52265  N03AX14         levetiracetam
# 3        54829  J01XA01            vancomycin
# 4        35943  A16AX05          zinc acetate
# ...        ...      ...                   ...
# 18910   608082  H01BA04          terlipressin
# 18911    42315  N05CD08             midazolam
# 18912    29767  N02BA01  acetylsalicylic acid
# 18913   584341  N05CD08             midazolam
# 18914   584342  N05CD08             midazolam
#
# [18915 rows x 3 columns]

# %%
atc_agg=atc.groupby("PROD_ID").aggregate({"ATC_COD":concatenate_values_from_list,"DESCR":concatenate_values_from_list}).reset_index()
atc_agg.columns=["PROD_ID","atc_code","atc_descr"]

# %%
product_with_routes_atc=product_with_routes.merge(atc_agg,on="PROD_ID",how="left")

# %%
cparm_pharm_forms=pd.read_excel("../CPARM_V1.0.xlsx","Pharmaceutical Dose Forms")
#remove duplicates terms (tablet for 12200 and 102190000)
cparm_pharm_forms["mapping_term"]=cparm_pharm_forms["Preferred Term (PT) PT | Termo de Preferência PT"]
cparm_pharm_forms["mapping_term"]=cparm_pharm_forms["mapping_term"].apply(lambda x: x.strip())
cparm_pharm_forms.loc[cparm_pharm_forms["Code EDQM |Código EDQM"]==11005000,"mapping_term"]="Solução retal"
cparm_pharm_forms=cparm_pharm_forms[cparm_pharm_forms["Definition EN | Definição EN"]!=" - "]

# %%
#for all (NOT DONE)
dose_forms_sql="""select * from ref_Forma_Farm """
dose_forms = pd.read_sql(dose_forms_sql,cnxn)
dose_forms
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/py3/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#      FORMA_FARM_ID                                              DESCR  \
# 0                0                                               N.A.
# 1                1                               Gotas orais, solução
# 2                2                             Gotas orais, suspensão
# 3                3                               Gotas orais, emulsão
# 4                4                                       Solução oral
# ..             ...                                                ...
# 510           1000                  Solução para perfusão em cartucho
# 511           1001                Gel oftálmico em recipiente unidose
# 512           1002                                Película sublingual
# 513           1003  Pó, dispersão e veículo para concentrado para ...
# 514           1004      Solução de libertação prolongada para feridas
#
#                   ABREV ABREV_CHNM IND_ATIVO
# 0                  None       None         S
# 1     Gotas orais, sol.   Sol oral         S
# 2    Gotas orais, susp.  Susp oral         S
# 3    Gotas orais, emul.  Emul oral         S
# 4             Sol. oral   Sol oral         S
# ..                  ...        ...       ...
# 510                None    Sol inj         S
# 511                None    Gel oft         S
# 512                None       None         S
# 513                None       None         S
# 514                None       None         S
#
# [515 rows x 5 columns]

# %%
selected_dose_forms=product_with_routes_atc[["form_farm_descr","Forma_farm_id"]]
selected_dose_forms.drop_duplicates(inplace=True)
selected_dose_forms
# Out:
# /var/folders/8g/rym67m5d29dcjm2td47sgb_m0000gn/T/ipykernel_37616/1619014294.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_dose_forms.drop_duplicates(inplace=True)
#                                          form_farm_descr  Forma_farm_id
# 0                                             Comprimido          271.0
# 2                                                Cápsula           29.0
# 4                                           Solução oral            4.0
# 5                      Comprimido revestido por película           39.0
# 17                  Pó e solvente para solução injetável          212.0
# ...                                                  ...            ...
# 46031                            Dispersão para perfusão          954.0
# 46356  Pó e solvente para concentrado para solução pa...          536.0
# 46417                     Solução para lavagem oftálmica          129.0
# 46753            Granulado e veículo para suspensão oral          542.0
# 46772                                               None            NaN
#
# [232 rows x 2 columns]

# %%
mapp_dose_form_edqm=selected_dose_forms.merge(cparm_pharm_forms,how="left",left_on="form_farm_descr",right_on="mapping_term")
mapp_dose_form_edqm[mapp_dose_form_edqm["Code EDQM |Código EDQM"].isnull()]
# Granulado orodispersível
# Sistema transdérmico	
# Solução injetável ou para perfusão
# Out:
#                                        form_farm_descr  Forma_farm_id  \
# 49         Colírio, comprimido e solvente para solução          900.0
# 55   Pó para solução injetável ou para solução para...          530.0
# 66                                Sistema transdérmico           98.0
# 68                 Solução oral + Pó para solução oral          311.0
# 79                           Pó para inalação, cápsula          198.0
# 99                  Solução injetável ou para perfusão          548.0
# 100                                Dispersão injetável          348.0
# 109               Granulado para solução oral ou retal          288.0
# 125              Solvente/Veículo para uso parentérico          220.0
# 126                              Creme vaginal + Óvulo          306.0
# 129             Pó para líquido para irrigação vesical          230.0
# 137                               Sistema transdérmico          963.0
# 141                           Gerador de radionuclidos          256.0
# 144  Pó e veículo para suspensão para uso intravesical          927.0
# 148  Granulado gastrorresistente de libertação prol...          948.0
# 155                   Colírio de libertação prolongada          128.0
# 158  Comprimido de libertação prolongada revestido ...          313.0
# 160           Solução para precursor radiofarmacêutico          383.0
# 167                                  Inserto oftálmico          131.0
# 169                    Pó para suspensão oral ou retal          317.0
# 173  Solução injetável ou concentrado para solução ...          833.0
# 175                    Soluções para cola para tecidos          834.0
# 189  Comprimido gastrorresistente de libertação pro...          946.0
# 191                Pó e solução para solução injetável          929.0
# 199                           Granulado orodispersível          952.0
# 201                  Comprimido revestido + Comprimido          527.0
# 202                            Película orodispersível          930.0
# 207                     Cápsula mole gastrorresistente           32.0
# 211                   Granulado em cápsulas para abrir          973.0
# 226  Substância de origem vegetal para inalação por...          996.0
# 230                     Solução para lavagem oftálmica          129.0
# 232                                               None            NaN
#
#      Code EDQM |Código EDQM  \
# 49                      NaN
# 55                      NaN
# 66                      NaN
# 68                      NaN
# 79                      NaN
# 99                      NaN
# 100                     NaN
# 109                     NaN
# 125                     NaN
# 126                     NaN
# 129                     NaN
# 137                     NaN
# 141                     NaN
# 144                     NaN
# 148                     NaN
# 155                     NaN
# 158                     NaN
# 160                     NaN
# 167                     NaN
# 169                     NaN
# 173                     NaN
# 175                     NaN
# 189                     NaN
# 191                     NaN
# 199                     NaN
# 201                     NaN
# 202                     NaN
# 207                     NaN
# 211                     NaN
# 226                     NaN
# 230                     NaN
# 232                     NaN
#
#     Fully Specified Name (FSN) EN | Termo Totalmente Especificado EN  \
# 49                                                 NaN
# 55                                                 NaN
# 66                                                 NaN
# 68                                                 NaN
# 79                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 109                                                NaN
# 125                                                NaN
# 126                                                NaN
# 129                                                NaN
# 137                                                NaN
# 141                                                NaN
# 144                                                NaN
# 148                                                NaN
# 155                                                NaN
# 158                                                NaN
# 160                                                NaN
# 167                                                NaN
# 169                                                NaN
# 173                                                NaN
# 175                                                NaN
# 189                                                NaN
# 191                                                NaN
# 199                                                NaN
# 201                                                NaN
# 202                                                NaN
# 207                                                NaN
# 211                                                NaN
# 226                                                NaN
# 230                                                NaN
# 232                                                NaN
#
#     Definition EN | Definição EN  \
# 49                           NaN
# 55                           NaN
# 66                           NaN
# 68                           NaN
# 79                           NaN
# 99                           NaN
# 100                          NaN
# 109                          NaN
# 125                          NaN
# 126                          NaN
# 129                          NaN
# 137                          NaN
# 141                          NaN
# 144                          NaN
# 148                          NaN
# 155                          NaN
# 158                          NaN
# 160                          NaN
# 167                          NaN
# 169                          NaN
# 173                          NaN
# 175                          NaN
# 189                          NaN
# 191                          NaN
# 199                          NaN
# 201                          NaN
# 202                          NaN
# 207                          NaN
# 211                          NaN
# 226                          NaN
# 230                          NaN
# 232                          NaN
#
#     Preferred Term (PT) PT | Termo de Preferência PT  \
# 49                                               NaN
# 55                                               NaN
# 66                                               NaN
# 68                                               NaN
# 79                                               NaN
# 99                                               NaN
# 100                                              NaN
# 109                                              NaN
# 125                                              NaN
# 126                                              NaN
# 129                                              NaN
# 137                                              NaN
# 141                                              NaN
# 144                                              NaN
# 148                                              NaN
# 155                                              NaN
# 158                                              NaN
# 160                                              NaN
# 167                                              NaN
# 169                                              NaN
# 173                                              NaN
# 175                                              NaN
# 189                                              NaN
# 191                                              NaN
# 199                                              NaN
# 201                                              NaN
# 202                                              NaN
# 207                                              NaN
# 211                                              NaN
# 226                                              NaN
# 230                                              NaN
# 232                                              NaN
#
#     Definition PT | Definição PT Domain | Âmbito  Version | Versão  \
# 49                           NaN              NaN              NaT
# 55                           NaN              NaN              NaT
# 66                           NaN              NaN              NaT
# 68                           NaN              NaN              NaT
# 79                           NaN              NaN              NaT
# 99                           NaN              NaN              NaT
# 100                          NaN              NaN              NaT
# 109                          NaN              NaN              NaT
# 125                          NaN              NaN              NaT
# 126                          NaN              NaN              NaT
# 129                          NaN              NaN              NaT
# 137                          NaN              NaN              NaT
# 141                          NaN              NaN              NaT
# 144                          NaN              NaN              NaT
# 148                          NaN              NaN              NaT
# 155                          NaN              NaN              NaT
# 158                          NaN              NaN              NaT
# 160                          NaN              NaN              NaT
# 167                          NaN              NaN              NaT
# 169                          NaN              NaN              NaT
# 173                          NaN              NaN              NaT
# 175                          NaN              NaN              NaT
# 189                          NaN              NaN              NaT
# 191                          NaN              NaN              NaT
# 199                          NaN              NaN              NaT
# 201                          NaN              NaN              NaT
# 202                          NaN              NaN              NaT
# 207                          NaN              NaN              NaT
# 211                          NaN              NaN              NaT
# 226                          NaN              NaN              NaT
# 230                          NaN              NaN              NaT
# 232                          NaN              NaN              NaT
#
#     Type of Change | Tipo Alteração mapping_term
# 49                              NaN          NaN
# 55                              NaN          NaN
# 66                              NaN          NaN
# 68                              NaN          NaN
# 79                              NaN          NaN
# 99                              NaN          NaN
# 100                             NaN          NaN
# 109                             NaN          NaN
# 125                             NaN          NaN
# 126                             NaN          NaN
# 129                             NaN          NaN
# 137                             NaN          NaN
# 141                             NaN          NaN
# 144                             NaN          NaN
# 148                             NaN          NaN
# 155                             NaN          NaN
# 158                             NaN          NaN
# 160                             NaN          NaN
# 167                             NaN          NaN
# 169                             NaN          NaN
# 173                             NaN          NaN
# 175                             NaN          NaN
# 189                             NaN          NaN
# 191                             NaN          NaN
# 199                             NaN          NaN
# 201                             NaN          NaN
# 202                             NaN          NaN
# 207                             NaN          NaN
# 211                             NaN          NaN
# 226                             NaN          NaN
# 230                             NaN          NaN
# 232                             NaN          NaN

# %%
cparm_pharm_forms=cparm_pharm_forms[["Code EDQM |Código EDQM","Fully Specified Name (FSN) EN | Termo Totalmente Especificado EN","Preferred Term (PT) PT | Termo de Preferência PT","mapping_term"]]
cparm_pharm_forms.columns=["edqm_dose_form_id","edqm_dose_form_descr_en","edqm_dose_form_descr_pt","mapping_term"]

# %%
#add to final dataframe
cparm_pharm_forms
product_with_routes_atc_edqm_dose=product_with_routes_atc.merge(cparm_pharm_forms,how="left",left_on="form_farm_descr",right_on="mapping_term")

# %%
product_with_routes_atc_edqm_dose
# Out:
#         EMB_ID  PROD_ID NR_REGISTO                                      DESCR  \
# 0            1        1    9929539                    Blister - 20 unidade(s)
# 1            3        1    9900423                    Blister - 40 unidade(s)
# 2            6        3    9935916                    Blister - 20 unidade(s)
# 3            7        3    9935924                   Blister - 200 unidade(s)
# 4           12        8    9650002  Frasco conta-gotas - 1 unidade(s) - 50 ml
# ...        ...      ...        ...                                        ...
# 46794  2205975    35283    5830625      Frasco para injetáveis - 5 unidade(s)
# 46795  2206095   685184       None         Recipiente unidose - 60 unidade(s)
# 46796  2206215   685284       None             Frasco - 1 unidade(s) - 250 ml
# 46797  2206335   685444       None              Ampola - 1 unidade(s) - 10 ml
# 46798  2206355   685464       None                      Frasco - 6 unidade(s)
#
#       GRUPO_HOM_COD  QUANT_TOT  UNID_QUANT_TOT_ID  QUANTIDADE  UNID_QUANT_ID  \
# 0            GH0000       20.0                 32         NaN            NaN
# 1            GH0000       40.0                 32         NaN            NaN
# 2            GH0000       20.0                 32         NaN            NaN
# 3            GH0000      200.0                 32         NaN            NaN
# 4            GH0000        1.0                 32        50.0           12.0
# ...             ...        ...                ...         ...            ...
# 46794        GH0000        5.0                 32         NaN            NaN
# 46795        GH0000       60.0                 32         NaN            NaN
# 46796        GH0000        1.0                 32       250.0           12.0
# 46797        GH0000        1.0                 32        10.0           12.0
# 46798        GH0000        6.0                 32         NaN            NaN
#
#        TIPO_EMB_ID  ...  routes_id     routes_descr  edqm_routes_id  \
# 0              NaN  ...         48         Via oral        20053000
# 1              NaN  ...         48         Via oral        20053000
# 2              NaN  ...         48         Via oral        20053000
# 3              NaN  ...         48         Via oral        20053000
# 4              NaN  ...         48         Via oral        20053000
# ...            ...  ...        ...              ...             ...
# 46794          NaN  ...         42  Via intravenosa        20045000
# 46795          NaN  ...         47    Uso oftálmico        20051000
# 46796          NaN  ...         48         Via oral        20053000
# 46797          NaN  ...         42  Via intravenosa        20045000
# 46798          NaN  ...         42  Via intravenosa        20045000
#
#       edqm_routes_descr_en atc_code                                 atc_descr  \
# 0                 Oral use  N02BA01                      acetylsalicylic acid
# 1                 Oral use  N02BA01                      acetylsalicylic acid
# 2                 Oral use  A11CA01                           retinol (vit A)
# 3                 Oral use  A11CA01                           retinol (vit A)
# 4                 Oral use  N06DX02                             Ginkgo folium
# ...                    ...      ...                                       ...
# 46794      Intravenous use  J01CR02  amoxicillin and beta-lactamase inhibitor
# 46795           Ocular use  S01EB01                               pilocarpine
# 46796             Oral use  A05AA02                      ursodeoxycholic acid
# 46797      Intravenous use  V09FX02                      sodium iodide (123I)
# 46798      Intravenous use  V09EB01              technetium (99mTc) macrosalb
#
#       edqm_dose_form_id              edqm_dose_form_descr_en  \
# 0            10219000.0                               Tablet
# 1            10219000.0                               Tablet
# 2               12100.0                              Capsule
# 3               12100.0                              Capsule
# 4            10105000.0                        Oral solution
# ...                 ...                                  ...
# 46794        11212000.0     Powder for solution for infusion
# 46795        10604000.0                  Eye drops, solution
# 46796        10106000.0                      Oral suspension
# 46797        11201000.0               Solution for injection
# 46798        11206000.0  Powder for suspension for injection
#
#              edqm_dose_form_descr_pt                   mapping_term
# 0                         Comprimido                     Comprimido
# 1                         Comprimido                     Comprimido
# 2                            Cápsula                        Cápsula
# 3                            Cápsula                        Cápsula
# 4                       Solução oral                   Solução oral
# ...                              ...                            ...
# 46794  Pó para solução para perfusão  Pó para solução para perfusão
# 46795               Colírio, solução               Colírio, solução
# 46796                 Suspensão oral                 Suspensão oral
# 46797              Solução injetável              Solução injetável
# 46798    Pó para suspensão injetável    Pó para suspensão injetável
#
# [46799 rows x 53 columns]

# %%
#testing with Amlor 10mg cápsulas caixa 100 - nao existe pt
#linha 137 - norvasc 10 mg caixa 30

# %%
#check for duplicates
product_with_routes_atc_edqm_dose[product_with_routes_atc_edqm_dose.duplicated(['EMB_ID'], keep=False)]
# Out:
#         EMB_ID  PROD_ID NR_REGISTO                   DESCR GRUPO_HOM_COD  \
# 45459  2160476   643465    5797204  Saqueta - 1 unidade(s)        GH0000
# 45460  2160476   643465    5797204  Saqueta - 1 unidade(s)        GH0000
#
#        QUANT_TOT  UNID_QUANT_TOT_ID  QUANTIDADE  UNID_QUANT_ID  TIPO_EMB_ID  \
# 45459        1.0                 32         NaN            NaN          NaN
# 45460        1.0                 32         NaN            NaN          NaN
#
#        ...  routes_id  routes_descr  edqm_routes_id edqm_routes_descr_en  \
# 45459  ...         48      Via oral        20053000             Oral use
# 45460  ...         48      Via oral        20053000             Oral use
#
#       atc_code                 atc_descr edqm_dose_form_id  \
# 45459  J07AE02  cholera, live attenuated        13119000.0
# 45460  J07AE02  cholera, live attenuated        13150000.0
#
#                                  edqm_dose_form_descr_en  \
# 45459  Effervescent powder and powder for oral suspen...
# 45460  Effervescent powder and suspension for oral su...
#
#                         edqm_dose_form_descr_pt  \
# 45459  Pó efervescente e pó para suspensão oral
# 45460  Pó efervescente e pó para suspensão oral
#
#                                    mapping_term
# 45459  Pó efervescente e pó para suspensão oral
# 45460  Pó efervescente e pó para suspensão oral
#
# [2 rows x 53 columns]

# %%
tt=product_with_routes_atc_edqm_dose["DCIPT_descr_parse"].unique()
list_unparse=[]
for ttt in tt:
    if ";" in ttt:
        for pl in ttt.split(";"):
            list_unparse.append(pl)
    else:
        list_unparse.append(ttt)

# %%
item_dict_parse= {k:v for k,v in zip(list_unparse,list(range(1,len(list_unparse)+1)))}

# %%
def mapp_dci_pt_parse(x,map):
    if ";" in x:
        p=[]
        for r in x.split(";"):
            p.append(str(map[r]))
        return ";".join(p)
    else:
        return map[x]

# %%
product_with_routes_atc_edqm_dose["DCIPT_id_parse"]=product_with_routes_atc_edqm_dose["DCIPT_descr_parse"].apply(mapp_dci_pt_parse,map=item_dict_parse)

# %%
product_with_routes_atc_edqm_dose
# Out:
#         EMB_ID  PROD_ID NR_REGISTO                                      DESCR  \
# 0            1        1    9929539                    Blister - 20 unidade(s)
# 1            3        1    9900423                    Blister - 40 unidade(s)
# 2            6        3    9935916                    Blister - 20 unidade(s)
# 3            7        3    9935924                   Blister - 200 unidade(s)
# 4           12        8    9650002  Frasco conta-gotas - 1 unidade(s) - 50 ml
# ...        ...      ...        ...                                        ...
# 46794  2205975    35283    5830625      Frasco para injetáveis - 5 unidade(s)
# 46795  2206095   685184       None         Recipiente unidose - 60 unidade(s)
# 46796  2206215   685284       None             Frasco - 1 unidade(s) - 250 ml
# 46797  2206335   685444       None              Ampola - 1 unidade(s) - 10 ml
# 46798  2206355   685464       None                      Frasco - 6 unidade(s)
#
#       GRUPO_HOM_COD  QUANT_TOT  UNID_QUANT_TOT_ID  QUANTIDADE  UNID_QUANT_ID  \
# 0            GH0000       20.0                 32         NaN            NaN
# 1            GH0000       40.0                 32         NaN            NaN
# 2            GH0000       20.0                 32         NaN            NaN
# 3            GH0000      200.0                 32         NaN            NaN
# 4            GH0000        1.0                 32        50.0           12.0
# ...             ...        ...                ...         ...            ...
# 46794        GH0000        5.0                 32         NaN            NaN
# 46795        GH0000       60.0                 32         NaN            NaN
# 46796        GH0000        1.0                 32       250.0           12.0
# 46797        GH0000        1.0                 32        10.0           12.0
# 46798        GH0000        6.0                 32         NaN            NaN
#
#        TIPO_EMB_ID  ...     routes_descr  edqm_routes_id  \
# 0              NaN  ...         Via oral        20053000
# 1              NaN  ...         Via oral        20053000
# 2              NaN  ...         Via oral        20053000
# 3              NaN  ...         Via oral        20053000
# 4              NaN  ...         Via oral        20053000
# ...            ...  ...              ...             ...
# 46794          NaN  ...  Via intravenosa        20045000
# 46795          NaN  ...    Uso oftálmico        20051000
# 46796          NaN  ...         Via oral        20053000
# 46797          NaN  ...  Via intravenosa        20045000
# 46798          NaN  ...  Via intravenosa        20045000
#
#        edqm_routes_descr_en atc_code  \
# 0                  Oral use  N02BA01
# 1                  Oral use  N02BA01
# 2                  Oral use  A11CA01
# 3                  Oral use  A11CA01
# 4                  Oral use  N06DX02
# ...                     ...      ...
# 46794       Intravenous use  J01CR02
# 46795            Ocular use  S01EB01
# 46796              Oral use  A05AA02
# 46797       Intravenous use  V09FX02
# 46798       Intravenous use  V09EB01
#
#                                       atc_descr edqm_dose_form_id  \
# 0                          acetylsalicylic acid        10219000.0
# 1                          acetylsalicylic acid        10219000.0
# 2                               retinol (vit A)           12100.0
# 3                               retinol (vit A)           12100.0
# 4                                 Ginkgo folium        10105000.0
# ...                                         ...               ...
# 46794  amoxicillin and beta-lactamase inhibitor        11212000.0
# 46795                               pilocarpine        10604000.0
# 46796                      ursodeoxycholic acid        10106000.0
# 46797                      sodium iodide (123I)        11201000.0
# 46798              technetium (99mTc) macrosalb        11206000.0
#
#                    edqm_dose_form_descr_en        edqm_dose_form_descr_pt  \
# 0                                   Tablet                     Comprimido
# 1                                   Tablet                     Comprimido
# 2                                  Capsule                        Cápsula
# 3                                  Capsule                        Cápsula
# 4                            Oral solution                   Solução oral
# ...                                    ...                            ...
# 46794     Powder for solution for infusion  Pó para solução para perfusão
# 46795                  Eye drops, solution               Colírio, solução
# 46796                      Oral suspension                 Suspensão oral
# 46797               Solution for injection              Solução injetável
# 46798  Powder for suspension for injection    Pó para suspensão injetável
#
#                         mapping_term DCIPT_id_parse
# 0                         Comprimido           2002
# 1                         Comprimido           2002
# 2                            Cápsula           1078
# 3                            Cápsula           1078
# 4                       Solução oral              3
# ...                              ...            ...
# 46794  Pó para solução para perfusão          65;64
# 46795               Colírio, solução            813
# 46796                 Suspensão oral            931
# 46797              Solução injetável           1224
# 46798    Pó para suspensão injetável           1261
#
# [46799 rows x 54 columns]

# %%
product_with_routes_atc_edqm_dose.columns
# Out:
# Index(['EMB_ID', 'PROD_ID', 'NR_REGISTO', 'DESCR', 'GRUPO_HOM_COD',
#        'QUANT_TOT', 'UNID_QUANT_TOT_ID', 'QUANTIDADE', 'UNID_QUANT_ID',
#        'TIPO_EMB_ID', 'ACOND_PRIMARIO_ID', 'TIPO_TRATAMENTO_ID',
#        'ESTADO_EMB_ID', 'IND_EMB_UNITARIA', 'IND_EMB_HOSPITALAR',
#        'IND_DISP_SEGURANCA', 'PEM_AMB', 'PEM_AMB_MS', 'PEM_AMB_BIO',
#        'PEM_AMB_BIO_MS', 'CNPEM', 'CHNM_COD', 'CDM', 'REFERENCIA',
#        'CARACT_ESPECIFICAS', 'Dosagem', 'Nome', 'ind_generico',
#        'form_farm_descr', 'Forma_farm_id', 'tipo_emb_descr', 'Tipo_prod_descr',
#        'Grupo_hom_descr', 'Estado_AIM_descr', 'Titular_AIM_descr',
#        'DCIPT_descr', 'DCIPT_ID', 'full_name', 'numerator_value',
#        'numerator_unit', 'denominator_value', 'denominator_unit',
#        'DCIPT_descr_parse', 'routes_id', 'routes_descr', 'edqm_routes_id',
#        'edqm_routes_descr_en', 'atc_code', 'atc_descr', 'edqm_dose_form_id',
#        'edqm_dose_form_descr_en', 'edqm_dose_form_descr_pt', 'mapping_term',
#        'DCIPT_id_parse'],
#       dtype='object')

# %%
def cleaning_strength(x):
    """
        UFC RIVM BCG
        U.I. anti-Xa
    """
    leftover_words=["Click"," RIVM BCG","(v","ELISA","anti-Xa","Anti-Xa","ONPG"," de Tice BCG"]
    if x is None:
        return None
    for w in leftover_words:
        if w in x:
            print(x)
            return x.replace(w,"").strip()
    else:
        return x




product_with_routes_atc_edqm_dose["numerator_unit"]=product_with_routes_atc_edqm_dose["numerator_unit"].apply(cleaning_strength)
product_with_routes_atc_edqm_dose["denominator_unit"]=product_with_routes_atc_edqm_dose["denominator_unit"].apply(cleaning_strength)
# Out:
# U.I. anti-Xa
# U.I. anti-Xa
# U.I. anti-Xa
# U.I. anti-Xa
# U.I. anti-Xa
# U.I. anti-Xa
# U.I. anti-Xa
# U.I. anti-Xa
# U.I. anti-Xa
# U ELISA
# U ELISA
# U ONPG
# U ONPG
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# U ONPG
# U ONPG
# UFC de Tice BCG
# UFC de Tice BCG
# UFC de Tice BCG
# U.I. anti-Xa
# U.I. anti-Xa
# U.I. anti-Xa
# U.I. anti-Xa
# U.I. anti-Xa
# U.I. anti-Xa
# U.I. anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# UFC RIVM BCG
# UFC RIVM BCG
# UFC RIVM BCG
# UFC RIVM BCG
# UFC RIVM BCG
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# UFC RIVM BCG
# % (v
# % (v
# % (v
# % (v
# % (v
# % (v
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I Anti-Xa
# U.I. anti-Xa
# U.I. anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I. Anti-Xa
# U.I Anti-Xa
# U.I Anti-Xa

# %%
product_with_routes_atc_edqm_dose.iloc[1389,:]
# Out:
# EMB_ID                                                                  7232
# PROD_ID                                                                 4346
# NR_REGISTO                                                           2296184
# DESCR                                         Cartucho - 5 unidade(s) - 3 ml
# GRUPO_HOM_COD                                                         GH0000
# QUANT_TOT                                                                5.0
# UNID_QUANT_TOT_ID                                                         32
# QUANTIDADE                                                               3.0
# UNID_QUANT_ID                                                           12.0
# TIPO_EMB_ID                                                              NaN
# ACOND_PRIMARIO_ID                                                         14
# TIPO_TRATAMENTO_ID                                                         2
# ESTADO_EMB_ID                                                              0
# IND_EMB_UNITARIA                                                           N
# IND_EMB_HOSPITALAR                                                         N
# IND_DISP_SEGURANCA                                                         S
# PEM_AMB                                                                    S
# PEM_AMB_MS                                                                 S
# PEM_AMB_BIO                                                                N
# PEM_AMB_BIO_MS                                                             N
# CNPEM                                                             50076035.0
# CHNM_COD                                                          10109560.0
# CDM                                                                     None
# REFERENCIA                                                              None
# CARACT_ESPECIFICAS                                                      None
# Dosagem                                              100 U.I./ml (30% + 70%)
# Nome                                                              Humulin M3
# ind_generico                                                               N
# form_farm_descr                                          Suspensão injetável
# Forma_farm_id                                                          208.0
# tipo_emb_descr                                                          None
# Tipo_prod_descr                                       Medicamento Uso Humano
# Grupo_hom_descr                                                         None
# Estado_AIM_descr                                                  Autorizado
# Titular_AIM_descr               Lilly-Portugal, Produtos Farmacêuticos, Lda.
# DCIPT_descr                            Insulina humana (solúvel + isofânica)
# DCIPT_ID                                                                3458
# full_name                  Humulin M3 100 U.I./ml (30% + 70%) Suspensão i...
# numerator_value                                                       100;70
# numerator_unit                                                       U.I.;%)
# denominator_value                                                          1
# denominator_unit                                                           %
# DCIPT_descr_parse                        Insulina humana (solúvel;isofânica)
# routes_id                                                              30;58
# routes_descr                                Via intramuscular;Via subcutânea
# edqm_routes_id                                             20035000;20066000
# edqm_routes_descr_en                      Intramuscular use;Subcutaneous use
# atc_code                                                             A10AD01
# atc_descr                                                    insulin (human)
# edqm_dose_form_id                                                 11202000.0
# edqm_dose_form_descr_en                             Suspension for injection
# edqm_dose_form_descr_pt                                  Suspensão injetável
# mapping_term                                             Suspensão injetável
# DCIPT_id_parse                                                       496;497
# skip                                                                     NaN
# skip_reason                                                              NaN
# Name: 1389, dtype: object

# %%
def correct_comb_strength(x):
    """
fix strength combinatory 
1. ml repeted
2. insulin TODO
    """
    #print(x)
    if x["denominator_value"] is None:
       # print("ssd")
        return x

    if ";" in x["numerator_value"] and ";" not in x["denominator_value"]:
        if "ml" in x["denominator_unit"]:
            x["denominator_value"]=x["denominator_value"]+";"+x["denominator_value"]
            x["denominator_unit"]=x["denominator_unit"]+";"+x["denominator_unit"]
        else: #insulin
            
            print(x[["numerator_value","numerator_unit","denominator_value","denominator_unit"]]) #%
        return x
      #  print(x.replace('"','\"'))
       # return x.replace('"','\"')
    else:
        return x

product_with_routes_atc_edqm_dose=product_with_routes_atc_edqm_dose.apply(correct_comb_strength,axis=1)
# Out:
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 1389, dtype: object
# numerator_value       100;85
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 1446, dtype: object
# numerator_value        40;85
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 1447, dtype: object
# numerator_value        40;85
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 1448, dtype: object
# numerator_value       100;85
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 1449, dtype: object
# numerator_value       100;85
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 1450, dtype: object
# numerator_value       100;75
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 1451, dtype: object
# numerator_value        40;75
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 1452, dtype: object
# numerator_value        40;75
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 1453, dtype: object
# numerator_value       100;75
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 1454, dtype: object
# numerator_value       100;75
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 1455, dtype: object
# numerator_value       100;50
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 1456, dtype: object
# numerator_value        40;50
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 1457, dtype: object
# numerator_value       100;50
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 1458, dtype: object
# numerator_value       100;50
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 1459, dtype: object
# numerator_value      100;75
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 3159, dtype: object
# numerator_value        40;50
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 3352, dtype: object
# numerator_value      10;150
# numerator_unit       mg;mg)
# denominator_value         1
# denominator_unit         g)
# Name: 3601, dtype: object
# numerator_value      100;70
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 5335, dtype: object
# numerator_value      100;70
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 5336, dtype: object
# numerator_value      100;75
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 6172, dtype: object
# numerator_value      100;50
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 6173, dtype: object
# numerator_value      100;75
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 6175, dtype: object
# numerator_value      100;50
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 6176, dtype: object
# numerator_value      100;75
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 6197, dtype: object
# numerator_value      100;50
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 6198, dtype: object
# numerator_value      100;70
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 6277, dtype: object
# numerator_value      100;70
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 6278, dtype: object
# numerator_value        40;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6970, dtype: object
# numerator_value        40;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6971, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6972, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6973, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6974, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6975, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6976, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6977, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6978, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6979, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6980, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6981, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6982, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6983, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6984, dtype: object
# numerator_value       100;60
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6985, dtype: object
# numerator_value       100;60
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6986, dtype: object
# numerator_value       100;60
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6987, dtype: object
# numerator_value       100;50
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6988, dtype: object
# numerator_value       100;50
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6989, dtype: object
# numerator_value       100;50
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6990, dtype: object
# numerator_value       100;60
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6991, dtype: object
# numerator_value       100;60
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6992, dtype: object
# numerator_value       100;50
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6993, dtype: object
# numerator_value       100;50
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6994, dtype: object
# numerator_value        40;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6995, dtype: object
# numerator_value        40;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6996, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6997, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6998, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 6999, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7000, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7001, dtype: object
# numerator_value       100;60
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7002, dtype: object
# numerator_value       100;60
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7003, dtype: object
# numerator_value       100;50
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7004, dtype: object
# numerator_value       100;50
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7005, dtype: object
# numerator_value       100;50
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7006, dtype: object
# numerator_value       100;50
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7007, dtype: object
# numerator_value       100;50
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7008, dtype: object
# numerator_value       100;60
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7009, dtype: object
# numerator_value       100;60
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7010, dtype: object
# numerator_value       100;60
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7011, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7012, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7013, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7014, dtype: object
# numerator_value       100;80
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7015, dtype: object
# numerator_value       100;80
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7016, dtype: object
# numerator_value       100;90
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7017, dtype: object
# numerator_value       100;90
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7018, dtype: object
# numerator_value       100;90
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7019, dtype: object
# numerator_value       100;90
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7020, dtype: object
# numerator_value       100;90
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7021, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7022, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7023, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7024, dtype: object
# numerator_value       100;80
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7025, dtype: object
# numerator_value       100;80
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7026, dtype: object
# numerator_value       100;80
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7027, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7028, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 7029, dtype: object
# numerator_value        40;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 12145, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 12146, dtype: object
# numerator_value        40;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 12147, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 12148, dtype: object
# numerator_value       100;85
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 15149, dtype: object
# numerator_value       100;85
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 15150, dtype: object
# numerator_value       100;75
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 15151, dtype: object
# numerator_value       100;75
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 15152, dtype: object
# numerator_value       100;50
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 15153, dtype: object
# numerator_value       100;50
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 15154, dtype: object
# numerator_value       100;85
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 15165, dtype: object
# numerator_value       100;85
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 15166, dtype: object
# numerator_value       100;85
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 15167, dtype: object
# numerator_value       100;85
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 15168, dtype: object
# numerator_value       100;75
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 15169, dtype: object
# numerator_value       100;75
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 15170, dtype: object
# numerator_value       100;75
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 15171, dtype: object
# numerator_value       100;75
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 15172, dtype: object
# numerator_value       100;50
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 15173, dtype: object
# numerator_value       100;50
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 15174, dtype: object
# numerator_value       100;50
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 15175, dtype: object
# numerator_value       100;50
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 15176, dtype: object
# numerator_value      100;50
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 15563, dtype: object
# numerator_value      100;50
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 15564, dtype: object
# numerator_value      100;50
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 15565, dtype: object
# numerator_value      100;30
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 15566, dtype: object
# numerator_value      100;30
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 15567, dtype: object
# numerator_value      100;30
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 15568, dtype: object
# numerator_value      100;50
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 15569, dtype: object
# numerator_value      100;50
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 15570, dtype: object
# numerator_value      100;50
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 15571, dtype: object
# numerator_value      100;30
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 15572, dtype: object
# numerator_value      100;30
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 15573, dtype: object
# numerator_value      100;30
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 15574, dtype: object
# numerator_value      100;75
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 16005, dtype: object
# numerator_value       100;75
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 20739, dtype: object
# numerator_value      100;50
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 23687, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 27618, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 27619, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 27620, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 27621, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 27622, dtype: object
# numerator_value       100;70
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 27623, dtype: object
# numerator_value       100;85
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 28029, dtype: object
# numerator_value       100;75
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 28030, dtype: object
# numerator_value       100;50
# numerator_unit       U.I.;%)
# denominator_value          1
# denominator_unit           %
# Name: 28031, dtype: object
# numerator_value      100;30
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 32279, dtype: object
# numerator_value      100;30
# numerator_unit         U;%)
# denominator_value         1
# denominator_unit          %
# Name: 45512, dtype: object

# %%
product_with_routes_atc_edqm_dose[product_with_routes_atc_edqm_dose["DCIPT_ID"].isin([174,3446,3600,3633])].to_csv("infarmed_export_v0_amlodipine_multiple.csv")

# %%
product_with_routes_atc_edqm_dose[product_with_routes_atc_edqm_dose.duplicated(["EMB_ID"])]
# Out:
#         EMB_ID  PROD_ID NR_REGISTO                   DESCR GRUPO_HOM_COD  \
# 45460  2160476   643465    5797204  Saqueta - 1 unidade(s)        GH0000
#
#        QUANT_TOT  UNID_QUANT_TOT_ID  QUANTIDADE  UNID_QUANT_ID  TIPO_EMB_ID  \
# 45460        1.0                 32         NaN            NaN          NaN
#
#        ...  routes_descr  edqm_routes_id  edqm_routes_descr_en atc_code  \
# 45460  ...      Via oral        20053000              Oral use  J07AE02
#
#                       atc_descr edqm_dose_form_id  \
# 45460  cholera, live attenuated        13150000.0
#
#                                  edqm_dose_form_descr_en  \
# 45460  Effervescent powder and suspension for oral su...
#
#                         edqm_dose_form_descr_pt  \
# 45460  Pó efervescente e pó para suspensão oral
#
#                                    mapping_term DCIPT_id_parse
# 45460  Pó efervescente e pó para suspensão oral           1297
#
# [1 rows x 54 columns]

# %%
product_with_routes_atc_edqm_dose.drop_duplicates().to_csv("infarmed_export_v0.csv")

# %%
with open('template-packaged-medicinal-product R5.fsh', 'r') as file:
    templateString = file.read()
t = Template(templateString,trim_blocks=True)

#DATA_FILE='infarmed_export_v0_amlodipine_multiple.csv'
DATA_FILE='infarmed_export_v0.csv'
df=pd.read_csv(DATA_FILE,index_col=0)
df=df.astype(str)
t.stream(data=df).dump('../../input/fsh/pt-pmp-r5-full.fsh')

# %%
# writing to file
file1 = open('../../input/fsh/pt-pmp-r5-full.fsh', 'r')
Lines = file1.readlines()
error_count=0
count = 0
final_count={}
# Strips the newline character
for line in Lines:
    count += 1
    if "// ERROR" in line:
        error_nr=re.search('ERROR\[\d{1,2}\]', line)
       # print(error_nr[0])
        if error_nr[0] in final_count.keys():
            final_count[error_nr[0]]+=1
        else:
            final_count[error_nr[0]]=1
        #print("{} @{}".format( line.strip(),count))
        error_count+=1

# %%
final_count
# Out:
# {'ERROR[5]': 2367,
#  'ERROR[2]': 51,
#  'ERROR[3]': 965,
#  'ERROR[7]': 31,
#  'ERROR[8]': 31,
#  'ERROR[1]': 1,
#  'ERROR[4]': 1}

# %%
print(error_count)
error_count/46919*100
# Out:
# 3447
# 7.346703893944884

# %%
#create skip row
def skip_row(x):
    if x["DCIPT_id_parse"] is None:
        return "X","no ID_parse"
    if  x["Dosagem"] in ["Associação","Combinação","associação"]:
        return "X","no strength number"
    if x["Forma_farm_id"] is None:
        return "X", "no Forma_farm_id"
    return np.nan,np.nan

product_with_routes_atc_edqm_dose[["skip","skip_reason"]]=product_with_routes_atc_edqm_dose.apply(skip_row,axis=1,result_type="expand")

# %% [markdown]
# ## Value Sets

# %%
#create valueset// Code System
f = open("../../input/fsh/terminology-ingredient-vs.fsh", "w")
f.write("CodeSystem: PTINGITEMCS\n")
f.write("Id:         pt-ingredient-item-cs\n")
f.write('Title:     ""\n')
f.write('Description: ""\n')
f.write("* ^url =  http://www.infarmed.pt/ingredients\n")
f.write("\n\n")

for k,v in item_dict_parse.items():
    f.write("* #"+str(v)+" "+"\n")
    f.write("  \""+k+"\""+ "\n")
    f.write("  \""+k+"\""+ "\n")

f.close()

# %%
#create valueset// Code System
f = open("../../input/fsh/terminology-edqm-routes-vs.fsh", "w")
f.write("""CodeSystem: EDQM-ROUTE-CS
Id:         edqm-route-cs
Title:     "Dose Form Ontology Code System"

* ^url = "http://www.edqm.eu/routes"
// * ^filter.code = #subform
// * ^filter.description = "Select codes that are childen of a given form"
// * ^filter.operator = #=
// * ^filter.value = "Select codes that are childen of a given form"

* ^property[+].code = #child
* ^property[=].type = #code
* ^property[=].uri = "http://hl7.org/fhir/concept-properties#child"

* ^property[+].code = #parent
* ^property[=].type = #code
* ^property[=].uri = "http://hl7.org/fhir/concept-properties#parent"

""")
f.write("\n\n")

for _,v in cparm_routes.iterrows():
    #print(k,v)
    f.write("* #"+str(v["Code EDQM |Código EDQM"])+" "+"\n")
    f.write("  \""+str(v["Fully Specified Name (FSN) EN | Termo Totalmente Especificado EN"])+"\""+ "\n")
    f.write("  \""+str(v["Definition EN | Definição EN"])+"\""+ "\n")

f.close()

# %%
#create valueset// Code System
f = open("../../input/fsh/terminology-edqm-dose-forms-vs.fsh", "w")
f.write("""CodeSystem: EDQM-DOSEFORM-CS
Id:         edqm-doseform-cs
Title:     "Dose Form Ontology Code System"

* ^url = "http://www.edqm.eu/dose-forms"
// * ^filter.code = #subform
// * ^filter.description = "Select codes that are childen of a given form"
// * ^filter.operator = #=
// * ^filter.value = "Select codes that are childen of a given form"

* ^property[+].code = #child
* ^property[=].type = #code
* ^property[=].uri = "http://hl7.org/fhir/concept-properties#child"

* ^property[+].code = #parent
* ^property[=].type = #code
* ^property[=].uri = "http://hl7.org/fhir/concept-properties#parent"

* ^hierarchyMeaning = #is-a
* #10219000
    "Tablet"
    "Tablet"
  * ^property[+].code = #child
  * ^property[=].valueCode = #10223000
  * ^property[+].code = #child
  * ^property[=].valueCode = #10226000
  * ^property[+].code = #child
  * ^property[=].valueCode = #10228000
  * ^property[+].code = #child
  * ^property[=].valueCode = #10220000
  * ^property[+].code = #child
  * ^property[=].valueCode = #10225000


  * #10223000
      "Orodispersible tablet"
      "Orodispersible tablet"
    * ^property[+].code = #parent
    * ^property[=].valueCode = #10219000

  * #10226000
      "Prolonged-release tablet"
      "Prolonged-release tablet"
    * ^property[+].code = #parent
    * ^property[=].valueCode = #10219000
  

  * #10228000
      "Chewable tablet"
      "Chewable tablet"
    * ^property[+].code = #parent
    * ^property[=].valueCode = #10219000


  * #10225000
      "Gastro-resistant tablet"
      "Gastro-resistant tablet"
    * ^property[+].code = #parent
    * ^property[=].valueCode = #10219000


  * #10220000
      "Coated tablet"
      "Coated tablet"
    * ^property[+].code = #parent
    * ^property[=].valueCode = #10219000

    * #10221000
      "Film-coated tablet"
      "Film-coated tablet"
      * ^property[+].code = #parent
      * ^property[=].valueCode = #10220000


* ^hierarchyMeaning = #is-a
* #12100
    "Capsule"
    "Capsule"
  * ^property[+].code = #child
  * ^property[=].valueCode = #10210000
  * ^property[+].code = #child
  * ^property[=].valueCode = #10211000 
  * ^property[+].code = #child
  * ^property[=].valueCode = #10214000 

  * #10210000
      "Capsule, hard"
      "Capsule, hard"
    * ^property[+].code = #parent
    * ^property[=].valueCode = #12100

  * #10211000
      "Capsule, soft"
      "Capsule, soft"
    * ^property[+].code = #parent
    * ^property[=].valueCode = #12100


  * #10214000
    "Chewable capsule, soft"
    "Chewable capsule, soft"
    * ^property[+].code = #parent
    * ^property[=].valueCode = #12100

* ^hierarchyMeaning = #is-a
* #11201000
    "Solution for injection"
    "Solution for injection"

* ^hierarchyMeaning = #is-a
* #11210000
    "Solution for infusion"
    "Solution for infusion"


* ^hierarchyMeaning = #is-a
* #10105000
    "Oral solution"
    "Oral solution"		

* ^hierarchyMeaning = #is-a
* #11207000
    "Powder and solvent for solution for injection"
    "Powder and solvent for solution for injection"	

""")
f.write("\n\n")

for _,v in cparm_pharm_forms.iterrows():
  if v["edqm_dose_form_id"] in [20003000,10221000,10220000,11207000,10105000,11210000,11201000,10214000,10211000,10210000,12100,10225000,10228000,10226000,10223000,10219000]:
    pass

  else:
    f.write("* ^hierarchyMeaning = #is-a\n")
    f.write("* #"+str(v["edqm_dose_form_id"])+" "+"\n")
    f.write("  \""+str(v["edqm_dose_form_descr_en"])+"\""+ "\n")
    f.write("  \""+str(v["edqm_dose_form_descr_en"])+"\""+ "\n")

f.close()

# %%
product_with_routes_atc_edqm_dose[product_with_routes_atc_edqm_dose["EMB_ID"]==2142793][["numerator_value","numerator_unit","denominator_value","denominator_unit"]]
# Out:
#       numerator_value numerator_unit denominator_value denominator_unit
# 43813             225             mg               1.5               ml

# %%
product_with_routes_atc_edqm_dose[product_with_routes_atc_edqm_dose.duplicated(subset=["EMB_ID"])]
#edqm dose form
# Out:
#         EMB_ID  PROD_ID NR_REGISTO                   DESCR GRUPO_HOM_COD  \
# 45460  2160476   643465    5797204  Saqueta - 1 unidade(s)        GH0000
#
#        QUANT_TOT  UNID_QUANT_TOT_ID  QUANTIDADE  UNID_QUANT_ID  TIPO_EMB_ID  \
# 45460        1.0                 32         NaN            NaN          NaN
#
#        ...  edqm_routes_descr_en  atc_code                 atc_descr  \
# 45460  ...              Oral use   J07AE02  cholera, live attenuated
#
#       edqm_dose_form_id                            edqm_dose_form_descr_en  \
# 45460        13150000.0  Effervescent powder and suspension for oral su...
#
#                         edqm_dose_form_descr_pt  \
# 45460  Pó efervescente e pó para suspensão oral
#
#                                    mapping_term DCIPT_id_parse skip  \
# 45460  Pó efervescente e pó para suspensão oral           1297  NaN
#
#       skip_reason
# 45460         NaN
#
# [1 rows x 56 columns]

# %%
product_with_routes_atc_edqm_dose[product_with_routes_atc_edqm_dose["EMB_ID"]==2160476]
# Out:
#         EMB_ID  PROD_ID NR_REGISTO                   DESCR GRUPO_HOM_COD  \
# 45459  2160476   643465    5797204  Saqueta - 1 unidade(s)        GH0000
# 45460  2160476   643465    5797204  Saqueta - 1 unidade(s)        GH0000
#
#        QUANT_TOT  UNID_QUANT_TOT_ID  QUANTIDADE  UNID_QUANT_ID  TIPO_EMB_ID  \
# 45459        1.0                 32         NaN            NaN          NaN
# 45460        1.0                 32         NaN            NaN          NaN
#
#        ...  edqm_routes_descr_en  atc_code                 atc_descr  \
# 45459  ...              Oral use   J07AE02  cholera, live attenuated
# 45460  ...              Oral use   J07AE02  cholera, live attenuated
#
#       edqm_dose_form_id                            edqm_dose_form_descr_en  \
# 45459        13119000.0  Effervescent powder and powder for oral suspen...
# 45460        13150000.0  Effervescent powder and suspension for oral su...
#
#                         edqm_dose_form_descr_pt  \
# 45459  Pó efervescente e pó para suspensão oral
# 45460  Pó efervescente e pó para suspensão oral
#
#                                    mapping_term DCIPT_id_parse skip  \
# 45459  Pó efervescente e pó para suspensão oral           1297  NaN
# 45460  Pó efervescente e pó para suspensão oral           1297  NaN
#
#       skip_reason
# 45459         NaN
# 45460         NaN
#
# [2 rows x 56 columns]

# %%
17441
#pt-pmp-119085
product_with_routes_atc_edqm_dose[product_with_routes_atc_edqm_dose["EMB_ID"]==46553][["numerator_value","numerator_unit","denominator_value","denominator_unit"]]
# Out:
#      numerator_value numerator_unit denominator_value denominator_unit
# 5218        500;1200          UI;UI             10;10            ml;ml

# %%
product_with_routes_atc_edqm_dose[product_with_routes_atc_edqm_dose["EMB_ID"]==46553].to_csv("test.csv")

# %%
product_with_routes_atc_edqm_dose
# Out:
#         EMB_ID  PROD_ID NR_REGISTO                                      DESCR  \
# 0            1        1    9929539                    Blister - 20 unidade(s)
# 1            3        1    9900423                    Blister - 40 unidade(s)
# 2            6        3    9935916                    Blister - 20 unidade(s)
# 3            7        3    9935924                   Blister - 200 unidade(s)
# 4           12        8    9650002  Frasco conta-gotas - 1 unidade(s) - 50 ml
# ...        ...      ...        ...                                        ...
# 46794  2205975    35283    5830625      Frasco para injetáveis - 5 unidade(s)
# 46795  2206095   685184       None         Recipiente unidose - 60 unidade(s)
# 46796  2206215   685284       None             Frasco - 1 unidade(s) - 250 ml
# 46797  2206335   685444       None              Ampola - 1 unidade(s) - 10 ml
# 46798  2206355   685464       None                      Frasco - 6 unidade(s)
#
#       GRUPO_HOM_COD  QUANT_TOT  UNID_QUANT_TOT_ID  QUANTIDADE  UNID_QUANT_ID  \
# 0            GH0000       20.0                 32         NaN            NaN
# 1            GH0000       40.0                 32         NaN            NaN
# 2            GH0000       20.0                 32         NaN            NaN
# 3            GH0000      200.0                 32         NaN            NaN
# 4            GH0000        1.0                 32        50.0           12.0
# ...             ...        ...                ...         ...            ...
# 46794        GH0000        5.0                 32         NaN            NaN
# 46795        GH0000       60.0                 32         NaN            NaN
# 46796        GH0000        1.0                 32       250.0           12.0
# 46797        GH0000        1.0                 32        10.0           12.0
# 46798        GH0000        6.0                 32         NaN            NaN
#
#        TIPO_EMB_ID  ...  edqm_routes_descr_en  atc_code  \
# 0              NaN  ...              Oral use   N02BA01
# 1              NaN  ...              Oral use   N02BA01
# 2              NaN  ...              Oral use   A11CA01
# 3              NaN  ...              Oral use   A11CA01
# 4              NaN  ...              Oral use   N06DX02
# ...            ...  ...                   ...       ...
# 46794          NaN  ...       Intravenous use   J01CR02
# 46795          NaN  ...            Ocular use   S01EB01
# 46796          NaN  ...              Oral use   A05AA02
# 46797          NaN  ...       Intravenous use   V09FX02
# 46798          NaN  ...       Intravenous use   V09EB01
#
#                                       atc_descr edqm_dose_form_id  \
# 0                          acetylsalicylic acid        10219000.0
# 1                          acetylsalicylic acid        10219000.0
# 2                               retinol (vit A)           12100.0
# 3                               retinol (vit A)           12100.0
# 4                                 Ginkgo folium        10105000.0
# ...                                         ...               ...
# 46794  amoxicillin and beta-lactamase inhibitor        11212000.0
# 46795                               pilocarpine        10604000.0
# 46796                      ursodeoxycholic acid        10106000.0
# 46797                      sodium iodide (123I)        11201000.0
# 46798              technetium (99mTc) macrosalb        11206000.0
#
#                    edqm_dose_form_descr_en        edqm_dose_form_descr_pt  \
# 0                                   Tablet                     Comprimido
# 1                                   Tablet                     Comprimido
# 2                                  Capsule                        Cápsula
# 3                                  Capsule                        Cápsula
# 4                            Oral solution                   Solução oral
# ...                                    ...                            ...
# 46794     Powder for solution for infusion  Pó para solução para perfusão
# 46795                  Eye drops, solution               Colírio, solução
# 46796                      Oral suspension                 Suspensão oral
# 46797               Solution for injection              Solução injetável
# 46798  Powder for suspension for injection    Pó para suspensão injetável
#
#                         mapping_term DCIPT_id_parse skip skip_reason
# 0                         Comprimido           2002  NaN         NaN
# 1                         Comprimido           2002  NaN         NaN
# 2                            Cápsula           1078  NaN         NaN
# 3                            Cápsula           1078  NaN         NaN
# 4                       Solução oral              3  NaN         NaN
# ...                              ...            ...  ...         ...
# 46794  Pó para solução para perfusão          65;64  NaN         NaN
# 46795               Colírio, solução            813  NaN         NaN
# 46796                 Suspensão oral            931  NaN         NaN
# 46797              Solução injetável           1224  NaN         NaN
# 46798    Pó para suspensão injetável           1261  NaN         NaN
#
# [46799 rows x 56 columns]
